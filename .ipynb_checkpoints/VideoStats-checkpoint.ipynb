# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from sklearn import linear_model
pd.set_option('display.float_format', lambda x: '%f' % x)

# %%
video_data = pd.read_csv('data.csv', header=None)

# %%
video_data[[24,72,168]].describe()
# Out:
#                   24              72              168
# count      916.000000      916.000000      916.000000
# mean    376765.517467   613303.341703   743209.837336
# std     923646.739985  1653969.423316  2007963.831213
# min      21173.000000    26162.000000    27139.000000
# 25%     124865.500000   148326.250000   153346.250000
# 50%     194357.500000   237417.500000   252287.000000
# 75%     326667.000000   433612.250000   522259.250000
# max   15284639.000000 22916701.000000 27898237.000000

# %%
video_data[168].hist(bins=50)

# %%
log_video_data = video_data.ix[:,1:].apply(np.log).replace([np.inf, -np.inf], np.nan).fillna(value=0)
log_video_data[168].hist(bins=50)

# %% [markdown]
# Looks like normal distribution.
#
# We have similar results to this popular paper:
#
# Gabor Szabo, Bernardo A. Huberman:  Predicting the popularity of online content

# %%
last_col_log = log_video_data[168]
log_clean_video_data = log_video_data[np.abs(last_col_log - last_col_log.mean()) <= (3*last_col_log.std())]

# %%
log_clean_video_data.shape
# Out:
# (901, 168)

# %%
for i in xrange(1,24):
    print "{} {}".format(i, log_clean_video_data[[i,168]].corr()[i][168])
# Out:
# 1 0.254538730486
# 2 0.784766630396
# 3 0.839769523076
# 4 0.855707427895
# 5 0.868397341276
# 6 0.880234403992
# 7 0.890877701641
# 8 0.901029007383
# 9 0.909913768305
# 10 0.916680712225
# 11 0.921825220471
# 12 0.926514244081
# 13 0.930555371925
# 14 0.934296896475
# 15 0.937993656305
# 16 0.94141611917
# 17 0.944743361696
# 18 0.947513658311
# 19 0.94990973856
# 20 0.952153689571
# 21 0.954276507379
# 22 0.956258130214
# 23 0.958027405797

# %%
msk = np.random.rand(len(log_clean_video_data)) < 0.9
video_train = log_clean_video_data[msk].ix[:,1:].as_matrix().T[..., np.newaxis]
video_test  = log_clean_video_data[~msk].ix[:,1:].as_matrix().T[..., np.newaxis]

# %%
video_train.shape, video_test.shape
# Out:
# ((168, 823, 1), (168, 78, 1))

# %%
lin_reg = []
for i in xrange(167):
    linear_regression = linear_model.LinearRegression()
    linear_regression.fit(video_train[i], video_train[-1])
    lin_reg += [linear_regression]

# %%
multi_lin_reg = []
for i in xrange(167):
    linear_regression = linear_model.LinearRegression()
    linear_regression.fit(video_train[:(i+1)].T.squeeze(axis=0), video_train[-1])
    multi_lin_reg += [linear_regression]

# %%
def mean_relative_squared_error(pred, groundtruth):
    return (((pred.flatten()/groundtruth.flatten()) - 1.0)**2).sum()/pred.shape[0]

def exp_mean_relative_squared_error(pred, groundtruth):
    return (((np.exp(pred.flatten() - groundtruth.flatten())) - 1.0)**2).sum()/pred.shape[0]

# %%
lin_res = []
multi_lin_res = []
for i in xrange(0,24):
    lin_res += [ exp_mean_relative_squared_error(
                    lin_reg[i].predict(video_test[i])
                  , video_test[-1]) ]
    multi_lin_res += [ exp_mean_relative_squared_error(
                          multi_lin_reg[i].predict(video_test[:(i+1)].T.squeeze(axis=0))
                        , video_test[-1]) ]

# %%
plt.title('Comparison of basic methods')
plt.xlabel('hour')
plt.ylabel('mRSE')
plt.plot(np.arange(1, 24+1), lin_res, marker='+', label='linear regression')
plt.plot(np.arange(1, 24+1), multi_lin_res, marker='+', label='multiple-input linear regression')
plt.legend()
plt.show()

# %% [markdown]
# ## Now the magic begins

# %%
import sklearn.svm

# %%
svr_reg = []
for i in xrange(24):
    svregression = sklearn.svm.SVR()
    svr_reg += [svregression.fit(video_train[i], video_train[-1].ravel())]

# %%
svr_res = []
for i in xrange(0,24):
    svr_res += [ exp_mean_relative_squared_error(
                    svr_reg[i].predict(video_test[i])
                  , video_test[-1]) ]

# %%
plt.title('Comparison of basic methods')
plt.xlabel('hour')
plt.ylabel('mRSE')
plt.plot(np.arange(1, 24+1), lin_res, marker='+', label='linear regression')
plt.plot(np.arange(1, 24+1), multi_lin_res, marker='+', label='multiple-input linear regression')
plt.plot(np.arange(1, 24+1), svr_res, marker='+', label='single-input support vector regression')
plt.legend()
plt.ylim(0, 0.5)
plt.show()

# %%
svr_reg[i].predict(video_test[10])/video_test[-1].flatten()
# Out:
# Shape: (78,)
# [ 0.94247288  0.9191068   0.97581951  0.97087039  0.97120326  0.97909722
#   0.97505634  0.96371487  0.93877092  0.98856305  1.11309662  0.98517567
#   0.96519525  0.95097297  0.98583848  0.98168755  0.98390792  0.96605703
#   0.97850441  0.90340054  0.97183551  0.9655817   0.97239275  0.98673924
#   0.87848456  0.9698865   0.97895028  0.96706106  0.98061496  0.98040334
#   0.99006879  0.98533183  0.96676455  0.93397215  0.97680708  0.98353474
#   0.88178956  0.98468021  0.96701493  0.97614422  0.9698796   1.08722784
#   0.94930548  0.97156465  0.97415792  0.95544066  0.97007966  0.9840201
#   0.97251046  0.97245776  0.97289315  0.96694647  0.94687983  0.95505914
#   0.99085442  0.96173136  0.96728439  0.96394202  0.97951826  0.99352141
#   0.96840052  0.94443569  0.97241739  0.9838198   0.9795017   0.98469124
#   0.95444967  0.94915448  0.97913742  0.962502    0.98996295  0.99412445
#   0.9800136   0.97193548  0.95976634  0.98009925  0.98181879  0.97129359]
